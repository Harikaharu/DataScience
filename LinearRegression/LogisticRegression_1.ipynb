# %% [markdown]
# <a href="https://colab.research.google.com/github/Harikaharu/DataScience/blob/main/LinearRegression/LogisticRegression_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('/content/insurance_data1.csv')
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
df.isnull().sum()
# Out:
# age                 0
# bought_insurance    0
# dtype: int64

# %%
plt.scatter(df.age,df.bought_insurance,marker='+',color='purple')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df[['age']],df.bought_insurance,train_size=0.8)
x_test
# Out:
#     age
# 21   26
# 24   50
# 5    56
# 9    61
# 17   58
# 12   27

# %%
df.shape
# Out:
# (27, 2)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
x_test
# Out:
#     age
# 21   26
# 24   50
# 5    56
# 9    61
# 17   58
# 12   27

# %%
model.predict(x_test)
# Out:
# array([0, 1, 1, 1, 1, 0])

# %%
y_predicted=model.predict(x_test)

# %%
model.predict_proba(x_test)
# Out:
# array([[0.81652362, 0.18347638],
#        [0.22325189, 0.77674811],
#        [0.1265557 , 0.8734443 ],
#        [0.07567958, 0.92432042],
#        [0.10339329, 0.89660671],
#        [0.79880016, 0.20119984]])
