# %% [markdown]
# <a href="https://colab.research.google.com/github/Harikaharu/DataScience/blob/main/MATPLOT/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[1,2,3,4,5,6,7,8,9]
y=[67,48,19,41,52,55,96,63,74]

# %%
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')
plt.plot(x,y,color='orange',linestyle='dotted',linewidth=5)

# %%
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')
plt.plot(x,y,'b+--')

# %%
plt.plot(x,y,color='blue',marker='+',linestyle=' ')

# %%
plt.plot(x,y,color='orange',marker='+',linestyle=' ',markersize=20)

# %%
plt.plot(x,y,'r>',alpha=1)

# %%
days=[1,2,3,4,5,6,7]
max_t=[50,51,52,48,47,49,46]
min_t=[43,42,40,44,33,35,37]
avg_t=[45,48,48,46,40,42,41]

# %%
plt.plot(days,max_t,label="max")
plt.plot(days,min_t,label="min")
plt.plot(days,avg_t,label="average")

# %%
plt.plot(days, max_t, label="max")
plt.plot(days, min_t, label="min")
plt.plot(days, avg_t, label="average")

plt.legend(loc='best')

# %% [markdown]
# # **Bar graphs**

# %%
company=['Google','amazon','msft',"facebook"]
revenue=[90,136,89,27]

# %%
import numpy as np
xpos=np.arange(len(company))
xpos
# Out:
# array([0, 1, 2, 3])

# %%
plt.bar(xpos,revenue,label="Revenue")
plt.xticks(xpos,company)
plt.ylabel("Revenue")
plt.title("Us technology stocks")
plt.legend()

# %%
profit=[40,2,34,12]

# %%
plt.bar(xpos-0.2,revenue,width=0.4,label="Revenue")
plt.bar(xpos+0.2,profit,width=0.4,label="Profit")
plt.xticks(xpos,company)
plt.ylabel("Revenue")
plt.title("Us technology stocks")
plt.legend()

# %%
plt.barh(xpos,revenue,label="Revenue")
# Out:
# <BarContainer object of 4 artists>

# %%
blood_sugar = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
plt.hist(blood_sugar, rwidth=0.8)
# Out:
# (array([3., 3., 1., 0., 1., 1., 0., 2., 0., 2.]),
#  array([ 77. ,  84.3,  91.6,  98.9, 106.2, 113.5, 120.8, 128.1, 135.4,
#         142.7, 150. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(blood_sugar,rwidth=0.5,bins=7)
# Out:
# (array([4., 3., 0., 2., 1., 1., 2.]),
#  array([ 77.        ,  87.42857143,  97.85714286, 108.28571429,
#         118.71428571, 129.14285714, 139.57142857, 150.        ]),
#  <BarContainer object of 7 artists>)

# %%
plt.xlabel("Sugar Level")
plt.ylabel("Number Of Patients")
plt.title("Blood Sugar Chart")

plt.hist(blood_sugar, bins=[80,100,125,150], rwidth=0.5, color='pink')
# Out:
# (array([6., 2., 4.]),
#  array([ 80., 100., 125., 150.]),
#  <BarContainer object of 3 artists>)

# %%
plt.xlabel("Sugar Level")
plt.ylabel("Number Of Patients")
plt.title("Blood Sugar Chart")

blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]

plt.hist([blood_sugar_men,blood_sugar_women], bins=[80,100,125,150], rwidth=0.95, color=['purple','pink'],label=['men','women'])
plt.legend()

# %%
plt.xlabel("Sugar Level")
plt.ylabel("Number Of Patients")
plt.title("Blood Sugar Chart")

plt.hist(blood_sugar,bins=[80,100,125,150],rwidth=0.95,histtype='step',color='purple')
# Out:
# (array([6., 2., 4.]),
#  array([ 80., 100., 125., 150.]),
#  [<matplotlib.patches.Polygon at 0x7ef5950add10>])

# %%
plt.xlabel("Number Of Patients")
plt.ylabel("Sugar Level")
plt.title("Blood Sugar Chart")

plt.hist(blood_sugar, bins=[80,100,125,150], rwidth=0.95, orientation='horizontal', color='orange')
# Out:
# (array([6., 2., 4.]),
#  array([ 80., 100., 125., 150.]),
#  <BarContainer object of 3 artists>)

# %% [markdown]
# # **Charts**

# %%
exp_vals=[1400,600,300,410,250]
exp_labels=["Home Rent","Food","Phone/Internet Bill","Car","Other Utilities"]
plt.pie(exp_vals,labels=exp_labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x7ef594db9f90>,
# ...
#  [Text(0.09328657754221462, 1.096037232237327, 'Home Rent'),
#   Text(-0.9822184851813743, -0.4952240375506892, 'Food'),
#   Text(-0.16284724404270376, -1.0878790259526545, 'Phone/Internet Bill'),
#   Text(0.6256102693619845, -0.9047716788609298, 'Car'),
#   Text(1.0615045165929147, -0.2884582487169374, 'Other Utilities')])

# %%
plt.pie(exp_vals,labels=exp_labels, shadow=True)
plt.axis("equal")
plt.show()

# %%
plt.axis("equal")
plt.pie(exp_vals,labels=exp_labels, shadow=True, autopct='%1.1f%%',radius=1.0)
plt.show()
# Out:
# WARNING:matplotlib.axes._base:Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.

# %%
plt.axis("equal")
plt.pie(exp_vals,labels=exp_labels, shadow=True, autopct='%1.1f%%',radius=1.0,explode=[0,0,0,0.1,0.2])
plt.show()
# Out:
# WARNING:matplotlib.axes._base:Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.

# %%
plt.axis("equal")
plt.pie(exp_vals,labels=exp_labels, shadow=True, autopct='%1.1f%%',radius=1.0,explode=[0,0,0,0.1,0.2],counterclock=True, startangle=45)
plt.show()
# Out:
# WARNING:matplotlib.axes._base:Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
