# %% [markdown]
# <a href="https://colab.research.google.com/github/Harikaharu/DataScience/blob/main/ML/LogisticRegression/LogisticRegression_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('/content/insurance_data1.csv')
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
df.isnull().sum()
# Out:
# age                 0
# bought_insurance    0
# dtype: int64

# %%
plt.scatter(df.age,df.bought_insurance,marker='+',color='purple')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df[['age']],df.bought_insurance,train_size=0.8)
x_test
# Out:
#     age
# 3    52
# 9    61
# 2    47
# 16   25
# 22   40
# 1    25

# %%
df.shape
# Out:
# (27, 2)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
x_test
# Out:
#     age
# 3    52
# 9    61
# 2    47
# 16   25
# 22   40
# 1    25

# %%
model.predict(x_test)
# Out:
# array([1, 1, 1, 0, 0, 0])

# %%
y_predicted=model.predict(x_test)

# %%
model.predict_proba(x_test)
# Out:
# array([[0.10516245, 0.89483755],
#        [0.01757224, 0.98242776],
#        [0.25062845, 0.74937155],
#        [0.97087429, 0.02912571],
#        [0.5912072 , 0.4087928 ],
#        [0.97087429, 0.02912571]])

# %%
model.score(x_test,y_test)
# Out:
# 0.5

# %%
y_predicted
# Out:
# array([1, 1, 1, 0, 0, 0])

# %%
x_test
# Out:
#     age
# 3    52
# 9    61
# 2    47
# 16   25
# 22   40
# 1    25

# %%
model.coef_
# Out:
# array([[0.2091745]])

# %%
model.intercept_
# Out:
# array([-8.73593819])

# %%
import math
def sigmoid(x):
  return 1/(1+math.exp(-x))

# %%
def prediction_function(age):
  z=0.11534631*age-4.65621816
  y=sigmoid(z)
  return y

# %%
age=35
prediction_function(age)
# Out:
# 0.3499867820026176

# %%
age=41
prediction_function(age)
# Out:
# 0.5182370437663316
